# %% [markdown]
# # Getting Financial Data from SEC Edgar

# %% [markdown]
# ## Automated processing using XBRL markup

# %% [markdown]
# Automated analysis of regulatory filings has become much easier since the SEC introduced XBRL, a free, open, and global standard for the electronic representation and exchange of business reports. XBRL is based on XML; it relies on taxonomies that define the meaning of the elements of a report and map to tags that highlight the corresponding information in the electronic version of the report. One such taxonomy represents the US Generally Accepted Accounting Principles (GAAP).
#
# The SEC introduced voluntary XBRL filings in 2005 in response to accounting scandals before requiring this format for all filers since 2009 and continues to expand the mandatory coverage to other regulatory filings. The SEC maintains a website that lists the current taxonomies that shape the content of different filings and can be used to extract specific items.
#
# There are several avenues to track and access fundamental data reported to the SEC:
#
# As part of the EDGAR Public Dissemination Service (PDS), electronic feeds of accepted filings are available for a fee.
# The SEC updates RSS feeds every 10 minutes, which list structured disclosure submissions.
# There are public index files for the retrieval of all filings through FTP for automated processing.
# The financial statement (and notes) datasets contain parsed XBRL data from all financial statements and the accompanying notes.
# The SEC also publishes log files containing the internet search traffic for EDGAR filings through SEC.gov, albeit with a six-month delay.

# %% [markdown]
# ## Building a fundamental data time series

# %% [markdown]
# The scope of the data in the Financial Statement and Notes datasets consists of numeric data extracted from the primary financial statements (Balance sheet, income statement, cash flows, changes in equity, and comprehensive income) and footnotes on those statements. The data is available as early as 2009.
#
# The folder 03_sec_edgar contains the notebook edgar_xbrl to download and parse EDGAR data in XBRL format, and create fundamental metrics like the P/E ratio by combining financial statement and price data.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

from pathlib import Path
from datetime import date
import json
from io import BytesIO
from zipfile import ZipFile, BadZipFile
import requests

import pandas_datareader.data as web
import pandas as pd

from pprint import pprint

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import h5py
from pandas import HDFStore

import requests, zipfile

# %%
sns.set_style('whitegrid')

# %%
data_path = Path('/Volumes/Seagate Backup Plus Drive/Parth Patel_Mac/SEC Data') # perhaps set to external harddrive to accomodate large amount of data
if not data_path.exists():
    data_path.mkdir()

# %% [markdown]
# The following code downloads and extracts all historical filings contained in the Financial Statement and Notes (FSN) datasets for the given range of quarters:

# %% [markdown]
# Downloading 40GB of Data

# %%
SEC_URL = 'https://www.sec.gov/files/dera/data/financial-statement-and-notes-data-sets/'

# %%
today = pd.Timestamp(date.today())
this_year = today.year
this_quarter = today.quarter
past_years = range(2009, this_year)

# %%
filing_periods = [(y, q) for y in past_years for q in range(1, 5)]
filing_periods.extend([(this_year, q) for q in range(1, this_quarter + 1)])

# %%
for i, (yr, qtr) in enumerate(filing_periods, 1):
    print(f'{yr}-Q{qtr}', end=' ', flush=True)
    filing = f'{yr}q{qtr}_notes.zip'
    
    path = data_path / f'{yr}_{qtr}' / 'source'
    
    if not path.exists():
        path.mkdir(exist_ok=True, parents=True)
    
    response = requests.get(SEC_URL + filing).content
    
    try:

        with ZipFile(BytesIO(response)) as zip_file:
            for file in zip_file.namelist():
                local_file = path / file
                
                if local_file.exists():
                    continue
                with local_file.open('wb') as output:
                    for line in zip_file.open(file).readlines():
                        output.write(line)
                        
    except BadZipFile:
        print('got bad zip file')
        continue
# Out:
# 2009-Q1 2009-Q2 2009-Q3 2009-Q4 2010-Q1 2010-Q2 2010-Q3 2010-Q4 2011-Q1 2011-Q2 2011-Q3 2011-Q4 2012-Q1 2012-Q2 2012-Q3 2012-Q4 2013-Q1 2013-Q2 2013-Q3 2013-Q4 2014-Q1 2014-Q2 2014-Q3 2014-Q4 2015-Q1 2015-Q2 2015-Q3 2015-Q4 2016-Q1 2016-Q2 2016-Q3 2016-Q4 2017-Q1 2017-Q2 2017-Q3 2017-Q4 2018-Q1 2018-Q2 2018-Q3 2018-Q4 2019-Q1 2019-Q2 2019-Q3 2019-Q4 2020-Q1 got bad zip file
# 2020-Q2 2020-Q3 got bad zip file
# 2020-Q4 got bad zip file

# %%
import dill as pickle
g = pickle.dumps(response)
pickle.loads(g)
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n\n<head>\n    <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    <meta http-equiv="content-type" content="text/html; charset=utf-8">\n    <meta name="viewport" content="width=device-width initial-scale=1.0 maximum-scale=3.0" />\n    <meta name="origin" content="WCM" />\n    <script type="text/javascript">\n\t  WebFontConfig = {\n\t    google: { families: [ \'Raleway:300,400,500,600:latin\' ] }\n\t  };\n\t  (function() {\n\t    var wf = document.createElement(\'script\');\n\t    wf.src = \'//ajax.googleapis.com/ajax/libs/webfont/1/webfont.js\';\n\t    wf.type = \'text/javascript\';\n\t    wf.async = \'true\';\n\t    var s = document.getElementsByTagName(\'script\')[0];\n\t    s.parentNode.insertBefore(wf, s);\n\t  })(); </script>\n    \n    <title>SEC.gov | File Not Found Error Alert (404)</title>\n    <link rel="stylesheet" property="stylesheet" type=\'text/css\' href=\'/layout/short-app.css\' />\n    <link rel="stylesheet" property="stylesheet" type=\'text/css\' href=\'/layout/short-shared.css\' />\n    <link rel="stylesheet" property="stylesheet" type=\'text/css\' href=\'/layout/footerstyle.css\' />\n\n    <script type=\'text/javascript\' src=\'/layout/jquery-1.7.1.min.js\'></script>\n    <script type=\'text/javascript\' src=\'/layout/respond.js\'></script>\n    <script type="text/javascript">\n        // adding the following class via JS allows for the creation of JS-specific style rules\n        $(\'html\').addClass(\'js\');\n    </script>\n\n    <!--[if lt IE 9]>\n  <script src="/ecms/js/third-party/html5shiv.js"></script>\n<![endif]-->\n</head>\n\n<body class="off-canvas hide-extras">\n    <!-- Google Tag Manager -->\n    <noscript>\n        <iframe src="//www.googletagmanager.com/ns.html?id=GTM-TD3BKV" height="0" width="0" style="display:none;visibility:hidden"></iframe>\n    </noscript>\n    <script type="text/javascript">\n        (function(w, d, s, l, i) {\n            w[l] = w[l] || [];\n            w[l].push({\n                \'gtm.start\': new Date().getTime(),\n                event: \'gtm.js\'\n            });\n            var f = d.getElementsByTagName(s)[0],\n                j = d.createElement(s),\n                dl = l != \'dataLayer\' ? \'&l=\' + l : \'\';\n            j.async = true;\n            j.src =\n                \'//www.googletagmanager.com/gtm.js?id=\' + i + dl;\n            f.parentNode.insertBefore(j, f);\n        })(window, document, \'script\', \'dataLayer\', \'GTM-TD3BKV\');\n    </script>\n    <!-- End Google Tag Manager -->\n    <div id="global-nav-bg-div" class="hide-for-medium-down"></div>\n    <div id="global-wrapper-bg-1" class="clearfix">\n        <div id="global-wrapper-bg-2">\n            <div id="global-wrapper-bg-3">\n                <div id="global-wrapper">\n                    <section role="main">\n                        <!-- section closed in footer.jsp -->\n                        <a tabindex="1" id="global-skip-nav" href="#main-content">Skip to Main Content</a>\n                        <div class="row hide-for-print" style="overflow: visible;">\n                            <div id="sidebarButton2" class="small-2 columns hide-for-medium-up">\n                                    <div class="smallTopBarButton"> </div>\n                                    <div class="smallTopBarButtonX2"> </div>\n                            </div>\n                            <div id="global-header" class="large-12">\n\t\t\t\t\t\t\t\t\n                          \t\t<div id="banner-seal">\n\t\t\t\t\t\t\t\t\t<a href="/index.html" tabindex="2">\n\t\t\t\t\t\t\t\t       <img src="/ecms/images/sec-logo.png" width="95" height="95" alt="U.S. Securities and Exchange Commission">\n\t\t\t\t\t\t\t\t    </a>\n\t\t\t\t\t\t\t    </div>\n\t\t\t\t\t\t\t       \n\t\t\t\t\t\t\t\t<div id="banner-org-name">\n\t\t\t\t\t\t\t\t\t<a href="/index.htm" tabindex="3">\n\t\t\t\t\t\t\t\t\t\tU.S. Securities and<br>Exchange Commission\n\t\t\t\t\t\t\t\t\t</a>\n\t\t\t\t\t\t\t\t   ...

# %% [markdown]
# # Finding the list of Companies(Sectorwise, CIK, Locationwise)

# %%
sp_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
sp500_constituents = pd.read_html(sp_url, header=0)[0]

# %%
sp500_constituents.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 9 columns):
# Symbol                   505 non-null object
# Security                 505 non-null object
# SEC filings              505 non-null object
# GICS Sector              505 non-null object
# GICS Sub-Industry        505 non-null object
# Headquarters Location    505 non-null object
# Date first added         450 non-null object
# CIK                      505 non-null int64
# Founded                  496 non-null object
# dtypes: int64(1), object(8)
# memory usage: 35.6+ KB

# %%
sp500_constituents.head()
# Out:
#   Symbol             Security SEC filings             GICS Sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                 GICS Sub-Industry    Headquarters Location Date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota       1976-08-09
# 1           Health Care Equipment  North Chicago, Illinois       1964-03-31
# 2                 Pharmaceuticals  North Chicago, Illinois       2012-12-31
# 3           Health Care Equipment   Danvers, Massachusetts       2018-05-31
# 4  IT Consulting & Other Services          Dublin, Ireland       2011-07-06
#
#        CIK      Founded
# 0    66740         1902
# 1     1800         1888
# 2  1551152  2013 (1888)
# 3   815094         1981
# 4  1467373         1989

# %%
Tech_stocks = sp500_constituents[sp500_constituents['GICS Sector'] == 'Information Technology']

# %%
Tech_stocks
# Out:
#     Symbol                                Security SEC filings  \
# 4      ACN                           Accenture plc     reports
# 6     ADBE                              Adobe Inc.     reports
# 7      AMD              Advanced Micro Devices Inc     reports
# 13    AKAM                 Akamai Technologies Inc     reports
# 38     APH                           Amphenol Corp     reports
# 39     ADI                    Analog Devices, Inc.     reports
# 40    ANSS                                   ANSYS     reports
# 46    AAPL                              Apple Inc.     reports
# 47    AMAT                  Applied Materials Inc.     reports
# 50    ANET                         Arista Networks     reports
# 55    ADSK                           Autodesk Inc.     reports
# 56     ADP               Automatic Data Processing     reports
# 77    AVGO                           Broadcom Inc.     reports
# 78      BR          Broadridge Financial Solutions     reports
# 82    CDNS                  Cadence Design Systems     reports
# 93     CDW                                     CDW     reports
# 108   CSCO                           Cisco Systems     reports
# 111   CTXS                          Citrix Systems     reports
# 116   CTSH          Cognizant Technology Solutions     reports
# 127    GLW                            Corning Inc.     reports
# 159    DXC                          DXC Technology     reports
# 184   FFIV                             F5 Networks     reports
# 189    FIS  Fidelity National Information Services     reports
# 193   FISV                              Fiserv Inc     reports
# 194    FLT               FleetCor Technologies Inc     reports
# 195   FLIR                            FLIR Systems     reports
# 199   FTNT                                Fortinet     reports
# 208     IT                             Gartner Inc     reports
# 216    GPN                    Global Payments Inc.     reports
# 228    HPE              Hewlett Packard Enterprise     reports
# ..     ...                                     ...         ...
# 315   MCHP                    Microchip Technology     reports
# 316     MU                       Micron Technology     reports
# 317   MSFT                         Microsoft Corp.     reports
# 326    MSI                 Motorola Solutions Inc.     reports
# 331   NTAP                                  NetApp     reports
# 344   NLOK                          NortonLifeLock     reports
# 348   NVDA                      Nvidia Corporation     reports
# 355   ORCL                            Oracle Corp.     reports
# 360   PAYX                            Paychex Inc.     reports
# 361   PAYC                                  Paycom     reports
# 362   PYPL                                  PayPal     reports
# 386   QRVO                                   Qorvo     reports
# 388   QCOM                           QUALCOMM Inc.     reports
# 406    CRM                          Salesforce.com     reports
# 409    STX                      Seagate Technology     reports
# 412    NOW                              ServiceNow     reports
# 415   SWKS                      Skyworks Solutions     reports
# 427   SNPS                           Synopsys Inc.     reports
# 434    TEL                    TE Connectivity Ltd.     reports
# 438    TER                                Teradyne     reports
# 439    TXN                       Texas Instruments     reports
# 450    TYL                      Tyler Technologies     reports
# 468   VRSN                           Verisign Inc.     reports
# 473      V                               Visa Inc.     reports
# 474    VNT                                 Vontier     reports
# 488    WDC                         Western Digital     reports
# 489     WU                        Western Union Co     reports
# 497    XRX                                   Xerox     reports
# 498   XLNX                                  Xilinx     reports
# 501   ZBRA                      Zebra Technologies     reports
#
#                 GICS Sector                           GICS Sub-Industry  \
# 4    Information Technology              IT Consulting & Other Services
# 6    Information Technology                        Application Software
# 7    Information Technology                              Semiconductors
# 13   Information Technology          Internet Services & Infrastructure
# 38   Information Technology                       Electronic Components
# 39   Information Technology                              Semiconductors
# 40   Information Technology                        Application Software
# 46   Information Technology  Technology Hardware, Storage & Peripherals
# 47   Information Technology                     Semiconductor Equipment
# 50   Information Technology                    Communications Equipment
# 55   Information Technology                        Application Software
# 56   Information Technology          Internet Services & Infrastructure
# 77   Information Technology                              Semiconductors
# 78   Information Technology       Data Processing & Outsourced Services
# 82   Information Technology                        Application Software
# 93   Information Technology                     Technology Distributors
# 108  Information Technology                    Communications Equipment
# 111  Information Technology                        Application Software
# 116  Information Technology              IT Consulting & Other Services
# 127  Information Technology                       Electronic Components
# 159  Information Technology              IT Consulting & Other Services
# 184  Information Technology                    Communications Equipment
# 189  Information Technology       Data Processing & Outsourced Services
# 193  Information Technology       Data Processing & Outsourced Services
# 194  Information Technology       Data Processing & Outsourced Services
# 195  Information Technology          Electronic Equipment & Instruments
# 199  Information Technology                            Systems Software
# 208  Information Technology              IT Consulting & Other Services
# 216  Information Technology       Data Processing & Outsourced Services
# 228  Information Technology  Technology Hardware, Storage & Peripherals
# ..                      ...                                         ...
# 315  Information Technology                              Semiconductors
# 316  Information Technology                              Semiconductors
# 317  Information Technology                            Systems Software
# 326  Information Technology                    Communications Equipment
# 331  Information Technology  Technology Hardware, Storage & Peripherals
# 344  Information Technology                        Application Software
# 348  Information Technology                              Semiconductors
# 355  Information Technology                        Application Software
# 360  Information Technology       Data Processing & Outsourced Services
# 361  Information Technology                        Application Software
# 362  Information Technology       Data Processing & Outsourced Services
# 386  Information Technology                              Semiconductors
# 388  Information Technology                              Semiconductors
# 406  Information Technology                        Application Software
# 409  Information Technology  Technology Hardware, Storage & Peripherals
# 412  Information Technology                            Systems Software
# 415  Information Technology                              Semiconductors
# 427  Information Technology                        Application Software
# 434  Information Technology           Electronic Manufacturing Services
# 438  Information Technology                     Semiconductor Equipment
# 439  Information Technology                              Semiconductors
# 450  Information Technology                        Application Software
# 468  Information Technology          Internet Services & Infrastructure
# 473  Information Technology       Data Processing & Outsourced Services
# 474  Information Technology          Electronic Equipment & Instruments
# 488  Information Technology  Technology Hardware, Storage & Peripherals
# 489  Information Technology       Data Processing & Outsourced Services
# 497  Information Technology  Technology Hardware, Storage & Peripherals
# 498  Information Technology                              Semiconductors
# 501  Information Technology          Electronic Equipment & Instruments
#
#             Headquarters Location Date first added      CIK      Founded
# 4                 Dublin, Ireland       2011-07-06  1467373         1989
# 6            San Jose, California       1997-05-05   796343         1982
# 7         Santa Clara, California       2017-03-20     2488         1969
# 13       Cambridge, Massachusetts       2007-07-12  1086222         1998
# 38       Wallingford, Connecticut       2008-09-30   820313         1932
# 39         Norwood, Massachusetts       1999-10-12     6281         1965
# 40       Canonsburg, Pennsylvania       2017-06-19  1013462         1969
# 46          Cupertino, California       1982-11-30   320193         1977
# 47        Santa Clara, California       1995-03-16     6951         1967
# 50        Santa Clara, California       2018-08-28  1596532         2004
# 55         San Rafael, California       1989-12-01   769397         1982
# 56           Roseland, New Jersey       1981-03-31     8670         1949
# 77           San Jose, California       2014-05-08  1730168         1961
# 78         Lake Success, New York       2018-06-18  1383312         1962
# 82           San Jose, California       2017-09-18   813672         1988
# 93         Lincolnshire, Illinois       2019-09-23  1402057         1984
# 108          San Jose, California       1993-12-01   858877         1984
# 111      Fort Lauderdale, Florida       1999-12-01   877890         1989
# 116           Teaneck, New Jersey       2006-11-17  1058290         1994
# 127             Corning, New York              NaN    24741         1851
# 159       Tysons Corner, Virginia       2017-04-04  1688568         2017
# 184           Seattle, Washington       2010-12-20  1048695         1996
# 189         Jacksonville, Florida       2006-11-10  1136893         1968
# 193         Brookfield, Wisconsin       2001-04-02   798354         1984
# 194             Norcross, Georgia       2018-06-20  1175454         2000
# 195           Wilsonville, Oregon       2009-01-02   354908         1978
# 199         Sunnyvale, California       2018-10-11  1262039         2000
# 208         Stamford, Connecticut       2017-04-05   749251         1979
# 216              Atlanta, Georgia       2016-04-25  1123360         2000
# 228         Palo Alto, California       2015-11-02  1645590         2015
# ..                            ...              ...      ...          ...
# 315             Chandler, Arizona       2007-09-07   827054         1989
# 316                  Boise, Idaho       1994-09-27   723125         1978
# 317           Redmond, Washington       1994-06-01   789019         1975
# 326             Chicago, Illinois              NaN    68505  1928 (2011)
# 331         Sunnyvale, California       1999-06-25  1002047         1992
# 344                Tempe, Arizona       2003-03-25   849399         1982
# 348       Santa Clara, California       2001-11-30  1045810         1993
# 355    Redwood Shores, California       1989-08-31  1341439         1977
# 360            Penfield, New York              NaN   723531         1971
# 361       Oklahoma City, Oklahoma       2020-01-28  1590955         1998
# 362          San Jose, California       2015-07-20  1633917         1998
# 386    Greensboro, North Carolina       2015-06-11  1604778         2015
# 388         San Diego, California              NaN   804328         1985
# 406     San Francisco, California       2008-09-15  1108524         1999
# 409               Dublin, Ireland       2012-07-02  1137789         1979
# 412       Santa Clara, California       2019-11-21  1373715         2003
# 415         Woburn, Massachusetts       2015-03-12     4127         2002
# 427     Mountain View, California       2017-03-16   883241         1986
# 434     Schaffhausen, Switzerland       2011-10-17  1385157         2007
# 438  North Reading, Massachusetts       2020-09-21    97210         1960
# 439                 Dallas, Texas              NaN    97476         1930
# 450                  Plano, Texas       2020-06-22   860731         1966
# 468              Dulles, Virginia       2006-02-01  1014473         1995
# 473     San Francisco, California       2009-12-21  1403161         1958
# 474       Raleigh, North Carolina       2020-10-09  1786842         2019
# 488          San Jose, California       2009-07-01   106040         1970
# 489           Englewood, Colorado       2006-09-29  1365135         1851
# 497          Norwalk, Connecticut              NaN  1770450         1906
# 498          San Jose, California       1999-11-08   743988         1984
# 501        Lincolnshire, Illinois       2019-12-23   877212         1969
#
# [73 rows x 9 columns]

# %% [markdown]
# # Save to parquet¶

# %% [markdown]
# The data is fairly large and to enable faster access than the original text files permit, it is better to convert the text files to binary, columnar parquet format (see Section 'Efficient data storage with pandas' in chapter 2 for a performance comparison of various data-storage options compatible with pandas DataFrames):

# %%
for f in data_path.glob('**/*.tsv'):
    file_name = f.stem  + '.parquet'
    path = Path(f.parents[1]) / 'parquet'
    if (path / file_name).exists():
        continue
    if not path.exists():
        path.mkdir(exist_ok=True)
    try:
        df = pd.read_csv(f, sep='\t', encoding='latin1', low_memory=False)
        print(df)
    except:
        print(f)
    df.to_parquet(path / file_name)

# %%
sub = pd.read_parquet(data_path / '2020_2' / 'parquet' / 'sub.parquet')
sub.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16411 entries, 0 to 16410
# Data columns (total 40 columns):
# adsh           16411 non-null object
# cik            16411 non-null int64
# name           16411 non-null object
# sic            16405 non-null float64
# countryba      16394 non-null object
# stprba         15137 non-null object
# cityba         16393 non-null object
# zipba          16384 non-null object
# bas1           16394 non-null object
# bas2           6591 non-null object
# baph           16392 non-null object
# countryma      16336 non-null object
# stprma         15167 non-null object
# cityma         16336 non-null object
# zipma          16325 non-null object
# mas1           16333 non-null object
# mas2           6488 non-null object
# countryinc     14973 non-null object
# stprinc        14076 non-null object
# ein            16411 non-null int64
# former         9595 non-null object
# changed        9595 non-null float64
# afs            16373 non-null object
# wksi           16411 non-null int64
# fye            16396 non-null float64
# form           16411 non-null object
# period         16410 non-null float64
# fy             6564 non-null float64
# fp             6564 non-null object
# filed          16411 non-null int64
# accepted       16411 non-null object
# prevrpt        16411 non-null int64
# detail         16411 non-null int64
# instance       16411 non-null object
# nciks          16411 non-null int64
# aciks          484 non-null object
# pubfloatusd    873 non-null float64
# floatdate      873 non-null float64
# floataxis      1 non-null object
# floatmems      1 non-null float64
# dtypes: float64(8), int64(7), object(25)
# memory usage: 5.0+ MB

# %% [markdown]
# # Get ADOBE submission¶

# %% [markdown]
# The submission dataset contains the unique identifiers required to retrieve the filings: the Central Index Key (CIK) and the Accession Number (adsh). The following shows some of the information about Adobe's 2020Q2 10-Q filing:

# %%
cik = 796343
company = sub[sub.cik == cik].T.dropna().squeeze()
key_cols = ['name', 'adsh', 'cik', 'name', 'sic', 'countryba', 'stprba',
            'cityba', 'zipba', 'bas1', 'form', 'period', 'fy', 'fp', 'filed']
company.loc[key_cols]
# Out:
# name            ADOBE SYSTEMS INC
# adsh         0000796343-13-000058
# cik                        796343
# name            ADOBE SYSTEMS INC
# sic                          7372
# countryba                      US
# stprba                         CA
# cityba                   SAN JOSE
# zipba                  95110-2704
# bas1                 345 PARK AVE
# form                         10-Q
# period                   20130831
# fy                           2013
# fp                             Q3
# filed                    20131003
# Name: 645, dtype: object

# %%
company_subs = pd.DataFrame()
for sub in data_path.glob('**/sub.parquet'):
    sub = pd.read_parquet(sub)
    company_sub = sub[(sub.cik.astype(int) == cik) & (sub.form.isin(['10-Q', '10-K']))]
    company_subs = pd.concat([company_subs, company_sub])

# %%
company_subs.form.value_counts()
# Out:
# 10-Q    33
# 10-K    10
# Name: form, dtype: int64

# %%
company_nums = pd.DataFrame()
for num in data_path.glob('**/num.parquet'):
    num = pd.read_parquet(num).drop('dimh', axis=1)
    company_num = num[num.adsh.isin(company_subs.adsh)]
    print(len(company_num))
    company_nums = pd.concat([company_nums, company_num])
company_nums.ddate = pd.to_datetime(company_nums.ddate, format='%Y%m%d')   
company_nums.to_parquet(data_path / 'company_nums.parquet')
# Out:
# 2528
# 1075
# 1091
# 0
# 2517
# 1066
# 1089
# 0
# 2473
# 1034
# 1045
# 0
# 2323
# 989
# 997
# 0
# 2270
# 986
# 999
# 0
# 2539
# 1365
# 1418
# 0
# 1170
# 0
# 258
# 0
# 1170
# 355
# 1019
# 1257
# 1230
# 1803
# 2197
# 0
# 1226
# 2846
# 1114
# 1096
# 0
# 2606
# 1137
# 0
# 1161

# %%
g = pickle.dumps(company_nums)
pickle.loads(g)
# Out:
#                          adsh  \
# 6840     0000796343-14-000004
# 6841     0000796343-14-000004
# 6842     0000796343-14-000004
# 6843     0000796343-14-000004
# 6844     0000796343-14-000004
# 6845     0000796343-14-000004
# 6846     0000796343-14-000004
# 6847     0000796343-14-000004
# 6848     0000796343-14-000004
# 6849     0000796343-14-000004
# 6850     0000796343-14-000004
# 6851     0000796343-14-000004
# 6852     0000796343-14-000004
# 6853     0000796343-14-000004
# 6854     0000796343-14-000004
# 6855     0000796343-14-000004
# 6856     0000796343-14-000004
# 6857     0000796343-14-000004
# 6858     0000796343-14-000004
# 6859     0000796343-14-000004
# 37077    0000796343-14-000023
# 37078    0000796343-14-000023
# 37079    0000796343-14-000023
# 37080    0000796343-14-000023
# 37081    0000796343-14-000023
# 37082    0000796343-14-000023
# 37083    0000796343-14-000023
# 37084    0000796343-14-000023
# 37085    0000796343-14-000023
# 37086    0000796343-14-000023
# ...                       ...
# 5092728  0000796343-13-000058
# 5092729  0000796343-13-000058
# 5092730  0000796343-13-000058
# 5092731  0000796343-13-000058
# 5092732  0000796343-13-000058
# 5092733  0000796343-13-000058
# 5092734  0000796343-13-000058
# 5092735  0000796343-13-000058
# 5092736  0000796343-13-000058
# 5092737  0000796343-13-000058
# 5092738  0000796343-13-000058
# 5092739  0000796343-13-000058
# 5092740  0000796343-13-000058
# 5092741  0000796343-13-000058
# 5092742  0000796343-13-000058
# 5092744  0000796343-13-000058
# 5092745  0000796343-13-000058
# 5092750  0000796343-13-000058
# 5092752  0000796343-13-000058
# 5092754  0000796343-13-000058
# 5092755  0000796343-13-000058
# 5092756  0000796343-13-000058
# 5092757  0000796343-13-000058
# 5092758  0000796343-13-000058
# 5092759  0000796343-13-000058
# 5092760  0000796343-13-000058
# 5092761  0000796343-13-000058
# 5092762  0000796343-13-000058
# 5092763  0000796343-13-000058
# 5092764  0000796343-13-000058
#
#                                                        tag  \
# 6840                               IncomeTaxExpenseBenefit
# 6841                               IncomeTaxExpenseBenefit
# 6842                               IncomeTaxExpenseBenefit
# 6843     StockIssuedDuringPeriodValueTreasuryStockReissued
# 6844     StockIssuedDuringPeriodValueTreasuryStockReissued
# 6845     AccumulatedOtherComprehensiveIncomeLossAvailab...
# 6846     AccumulatedOtherComprehensiveIncomeLossAvailab...
# 6847     AvailableForSaleSecuritiesDebtMaturitiesWithin...
# 6848                 ProceedsFromSaleOfPropertyHeldForSale
# 6849     AvailableForSaleSecuritiesInUnrealizedLossPosi...
# 6850     AvailableForSaleSecuritiesInUnrealizedLossPosi...
# 6851                                 DeferredTaxAttributes
# 6852     SecuritiesInContinuousUnrealizedLossPositionFo...
# 6853     StockIssuedDuringPeriodValueTreasuryStockReissued
# 6854                           CostOfGoodsSoldAmortization
# 6855                           CostOfGoodsSoldAmortization
# 6856                           CostOfGoodsSoldAmortization
# 6857     DeferredTaxLiabilitiesUndistributedForeignEarn...
# 6858     DeferredTaxLiabilitiesUndistributedForeignEarn...
# 6859                    EntityCommonStockSharesOutstanding
# 37077                                          GrossProfit
# 37078                                          GrossProfit
# 37079                                GainLossOnInvestments
# 37080                                GainLossOnInvestments
# 37081    IncrementalCommonSharesAttributableToShareBase...
# 37082    IncrementalCommonSharesAttributableToShareBase...
# 37083    OtherThanTemporaryImpairmentLossesInvestmentsP...
# 37084                              SalesRevenueServicesNet
# 37085                              SalesRevenueServicesNet
# 37086                 DueAfterThreeYearsEstimatedFairValue
# ...                                                    ...
# 5092728  ShareBasedCompensationArrangementByShareBasedP...
# 5092729  ShareBasedCompensationArrangementByShareBasedP...
# 5092730  ShareBasedCompensationArrangementByShareBasedP...
# 5092731     AvailableForSaleSecuritiesGrossUnrealizedGains
# 5092732            AvailableForSaleSecuritiesAmortizedCost
# 5092733                         AvailableForSaleSecurities
# 5092734      AvailableForSaleSecuritiesGrossUnrealizedLoss
# 5092735                               RestructuringReserve
# 5092736                               RestructuringReserve
# 5092737                           PaymentsForRestructuring
# 5092738            RestructuringAndRelatedCostExpectedCost
# 5092739  RestructuringReserveTranslationAndOtherAdjustment
# 5092740            RestructuringAndRelatedCostIncurredCost
# 5092741      RestructuringAndRelatedCostCostIncurredToDate
# 5092742                           PaymentsForRestructuring
# 5092744                               RestructuringReserve
# 5092745                               RestructuringReserve
# 5092750  RestructuringReserveTranslationAndOtherAdjustment
# 5092752            RestructuringAndRelatedCostIncurredCost
# 5092754     AvailableForSaleSecuritiesGrossUnrealizedGains
# 5092755            AvailableForSaleSecuritiesAmortizedCost
# 5092756                         AvailableForSaleSecurities
# 5092757      AvailableForSaleSecuritiesGrossUnrealizedLoss
# 5092758         MaximumTargetPercentageAllowedUnderProgram
# 5092759                           ActualPercentageAchieved
# 5092760                               ActualSharesAchieved
# 5092761         MaximumTargetPercentageAllowedUnderProgram
# 5092762                           ActualPercentageAchieved
# 5092763                               ActualSharesAchieved
# 5092764         MaximumTargetPercentageAllowedUnderProgram
#
#                       version      ddate qtrs         uom  iprx         value  \
# 6840             us-gaap/2013 2013-11-30    4         USD   0.0  6.615600e+07
# 6841             us-gaap/2013 2012-11-30    4         USD   0.0  2.860190e+08
# 6842             us-gaap/2013 2011-11-30    4         USD   0.0  2.023830e+08
# 6843             us-gaap/2013 2011-11-30    4         USD   0.0  1.447540e+08
# 6844             us-gaap/2013 2012-11-30    4         USD   0.0  1.692740e+08
# 6845             us-gaap/2013 2013-11-30    0         USD   0.0  9.241000e+06
# 6846             us-gaap/2013 2012-11-30    0         USD   0.0  1.443900e+07
# 6847             us-gaap/2013 2013-11-30    0         USD   0.0  5.094380e+08
# 6848             us-gaap/2013 2013-11-30    1         USD   0.0  2.430000e+07
# 6849     0000796343-14-000004 2012-11-30    0  securities   0.0  6.500000e+01
# 6850     0000796343-14-000004 2013-11-30    0  securities   0.0  1.770000e+02
# 6851     0000796343-14-000004 2013-11-30    0         USD   0.0  4.700000e+07
# 6852     0000796343-14-000004 2012-11-30    0  securities   0.0  1.000000e+00
# 6853             us-gaap/2013 2013-11-30    4         USD   0.0  5.007760e+08
# 6854             us-gaap/2013 2012-11-30    4         USD   0.0  9.830000e+07
# 6855             us-gaap/2013 2013-11-30    4         USD   0.0  1.110000e+08
# 6856             us-gaap/2013 2011-11-30    4         USD   0.0  8.830000e+07
# 6857             us-gaap/2013 2012-11-30    0         USD   0.0  1.875280e+08
# 6858             us-gaap/2013 2013-11-30    0         USD   0.0  2.114170e+08
# 6859                 dei/2013 2014-01-31    0      shares   0.0  4.966045e+08
# 37077            us-gaap/2013 2013-02-28    1         USD   0.0  8.511890e+08
# 37078            us-gaap/2013 2014-02-28    1         USD   0.0  8.516110e+08
# 37079            us-gaap/2013 2013-02-28    1         USD   0.0  8.480000e+05
# 37080            us-gaap/2013 2014-02-28    1         USD   0.0 -4.090000e+05
# 37081            us-gaap/2013 2013-02-28    1      shares   0.0  2.707000e+06
# 37082            us-gaap/2013 2014-02-28    1      shares   0.0  2.495000e+06
# 37083            us-gaap/2013 2014-02-28    1         USD   0.0  0.000000e+00
# 37084            us-gaap/2013 2014-02-28    1         USD   0.0  1.051030e+08
# 37085            us-gaap/2013 2013-02-28    1         USD   0.0  1.078180e+08
# 37086    0000796343-14-000023 2014-02-28    0         USD   0.0  2.138690e+08
# ...                       ...        ...  ...         ...   ...           ...
# 5092728          us-gaap/2013 2013-08-31    3      shares   0.0  9.460000e+05
# 5092729          us-gaap/2013 2013-08-31    0      shares   0.0  8.620000e+05
# 5092730          us-gaap/2013 2012-11-30    0      shares   0.0  0.000000e+00
# 5092731          us-gaap/2013 2013-08-31    3         USD   0.0  1.000000e+03
# 5092732          us-gaap/2013 2013-08-31    0         USD   0.0  1.499900e+07
# 5092733          us-gaap/2013 2013-08-31    0         USD   0.0  1.500000e+07
# 5092734          us-gaap/2013 2013-08-31    3         USD   0.0  0.000000e+00
# 5092735          us-gaap/2013 2012-11-30    0         USD   0.0  9.623000e+06
# 5092736          us-gaap/2013 2013-08-31    0         USD   0.0  3.595000e+06
# 5092737          us-gaap/2013 2013-08-31    3         USD   0.0  1.161000e+06
# 5092738          us-gaap/2013 2013-08-31    8         USD   0.0  9.700000e+06
# 5092739          us-gaap/2013 2013-08-31    3         USD   0.0 -4.867000e+06
# 5092740          us-gaap/2013 2013-08-31    3         USD   0.0  0.000000e+00
# 5092741          us-gaap/2013 2013-08-31    8         USD   0.0  9.700000e+06
# 5092742          us-gaap/2013 2013-08-31    3         USD   0.0  7.600000e+05
# 5092744          us-gaap/2013 2012-11-30    0         USD   0.0  1.248000e+06
# 5092745          us-gaap/2013 2013-08-31    0         USD   0.0  4.300000e+05
# 5092750          us-gaap/2013 2013-08-31    3         USD   0.0 -5.800000e+04
# 5092752          us-gaap/2013 2013-08-31    3         USD   0.0  0.000000e+00
# 5092754          us-gaap/2013 2012-11-30    4         USD   0.0  0.000000e+00
# 5092755          us-gaap/2013 2012-11-30    0         USD   0.0  2.011300e+07
# 5092756          us-gaap/2013 2012-11-30    0         USD   0.0  2.011300e+07
# 5092757          us-gaap/2013 2012-11-30    4         USD   0.0  0.000000e+00
# 5092758  0000796343-13-000058 2012-11-30    4        pure   0.0  1.500000e+00
# 5092759  0000796343-13-000058 2012-11-30    4        pure   0.0  1.160000e+00
# 5092760  0000796343-13-000058 2012-11-30    4      shares   0.0  1.300000e+06
# 5092761  0000796343-13-000058 2011-11-30    4        pure   0.0  1.500000e+00
# 5092762  0000796343-13-000058 2011-11-30    4        pure   0.0  1.300000e+00
# 5092763  0000796343-13-000058 2011-11-30    4      shares   0.0  5.000000e+05
# 5092764  0000796343-13-000058 2013-08-31    3        pure   0.0  2.000000e+00
#
#         footnote footlen dimn coreg      durp  datp     dcml
# 6840        None       0    0  None  0.021918   1.0     -3.0
# 6841        None       0    0  None  0.021918   0.0     -3.0
# 6842        None       0    0  None  0.021918  -2.0     -3.0
# 6843        None       0    0  None  0.021918  -2.0     -3.0
# 6844        None       0    0  None  0.021918   0.0     -3.0
# 6845        None       0    0  None  0.000000   1.0     -3.0
# 6846        None       0    0  None  0.000000   0.0     -3.0
# 6847        None       0    0  None  0.000000   1.0     -3.0
# 6848        None       0    0  None  0.013699   1.0     -5.0
# 6849        None       0    0  None  0.000000   0.0      0.0
# 6850        None       0    0  None  0.000000   1.0      0.0
# 6851        None       0    0  None  0.000000   1.0     -5.0
# 6852        None       0    0  None  0.000000   0.0  32767.0
# 6853        None       0    0  None  0.021918   1.0     -3.0
# 6854        None       0    0  None  0.021918   0.0     -5.0
# 6855        None       0    0  None  0.021918   1.0     -5.0
# 6856        None       0    0  None  0.021918  -2.0     -5.0
# 6857        None       0    0  None  0.000000   0.0     -3.0
# 6858        None       0    0  None  0.000000   1.0     -3.0
# 6859        None       0    0  None  0.000000  14.0      0.0
# 37077       None       0    0  None  0.013699  -1.0     -3.0
# 37078       None       0    0  None  0.013699   0.0     -3.0
# 37079       None       0    0  None  0.013699  -1.0     -3.0
# 37080       None       0    0  None  0.013699   0.0     -3.0
# 37081       None       0    0  None  0.013699  -1.0     -3.0
# 37082       None       0    0  None  0.013699   0.0     -3.0
# 37083       None       0    0  None  0.013699   0.0     -3.0
# 37084       None       0    0  None  0.013699   0.0     -3.0
# 37085       None       0    0  None  0.013699  -1.0     -3.0
# 37086       None       0    0  None  0.000000   0.0     -3.0
# ...          ...     ...  ...   ...       ...   ...      ...
# 5092728     None       0    3  None  0.019179   1.0     -3.0
# 5092729     None       0    3  None  0.000000   1.0     -3.0
# 5092730     None       0    3  None  0.000000   0.0     -3.0
# 5092731     None       0    2  None  0.019179   1.0     -3.0
# 5092732     None       0    2  None  0.000000   1.0     -3.0
# 5092733     None       0    2  None  0.000000   1.0     -3.0
# 5092734     None       0    2  None  0.019179   1.0     -3.0
# 5092735     None       0    2  None  0.000000   0.0     -3.0
# 5092736     None       0    2  None  0.000000   1.0     -3.0
# 5092737     None       0    2  None  0.019179   1.0     -3.0
# 5092738     None       0    2  None  0.032877   1.0     -5.0
# 5092739     None       0    2  None  0.019179   1.0     -3.0
# 5092740     None       0    2  None  0.019179   1.0     -3.0
# 5092741     None       0    2  None  0.032877   1.0     -5.0
# 5092742     None       0    2  None  0.019179   1.0     -3.0
# 5092744     None       0    2  None  0.000000   0.0     -3.0
# 5092745     None       0    2  None  0.000000   1.0     -3.0
# 5092750     None       0    2  None  0.019179   1.0     -3.0
# 5092752     None       0    2  None  0.019179   1.0     -3.0
# 5092754     None       0    2  None  0.021918   0.0     -3.0
# 5092755     None       0    2  None  0.000000   0.0     -3.0
# 5092756     None       0    2  None  0.000000   0.0     -3.0
# 5092757     None       0    2  None  0.021918   0.0     -3.0
# 5092758     None       0    2  None  0.021918   0.0  32767.0
# 5092759     None       0    2  None  0.021918   0.0  32767.0
# 5092760     None       0    2  None  0.021918   0.0     -5.0
# 5092761     None       0    2  None  0.021918  -2.0  32767.0
# 5092762     None       0    2  None  0.021918  -2.0  32767.0
# 5092763     None       0    2  None  0.021918  -2.0     -5.0
# 5092764     None       0    2  None  0.019179   1.0  32767.0
#
# [49449 rows x 15 columns]

# %%
company_nums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49449 entries, 6840 to 5092764
# Data columns (total 15 columns):
# adsh        49449 non-null object
# tag         49449 non-null object
# version     49449 non-null object
# ddate       49449 non-null datetime64[ns]
# qtrs        49449 non-null object
# uom         49449 non-null object
# iprx        49449 non-null float64
# value       49409 non-null float64
# footnote    523 non-null object
# footlen     49449 non-null object
# dimn        49449 non-null object
# coreg       0 non-null object
# durp        49449 non-null float64
# datp        49449 non-null float64
# dcml        49449 non-null float64
# dtypes: datetime64[ns](1), float64(5), object(9)
# memory usage: 6.0+ MB

# %% [markdown]
# # Create P/E Ratio from EPS and stock price data

# %% [markdown]
# We can select a useful field, such as Earnings per Diluted Share (EPS), that we can combine with market data to calculate the popular Price/Earnings (P/E) valuation ratio.

# %%
stock_split = 0
split_date = pd.to_datetime('20140604')
split_date
# Out:
# Timestamp('2014-06-04 00:00:00')

# %%
# Filter by tag; keep only values measuring 1 quarter
eps = company_nums[(company_nums.tag == 'EarningsPerShareDiluted')
                & (company_nums.qtrs == 1)].drop('tag', axis=1)

# Keep only most recent data point from each filing
eps = eps.groupby('adsh').apply(lambda x: x.nlargest(n=1, columns=['ddate']))

# Adjust earnings prior to stock split downward
eps.loc[eps.ddate < split_date,'value'] = eps.loc[eps.ddate < split_date, 'value'].div(7)
eps = eps[['ddate', 'value']].set_index('ddate').squeeze().sort_index()
eps = eps.rolling(4,min_periods=4).sum().dropna()

# %%
eps.plot(lw=2, figsize=(14, 6), title='Diluted Earnings per Share')
plt.xlabel('')
plt.savefig('diluted eps', dps=300);

# %%
symbol = 'ADBE.US'
 

company_stock = (web.
              DataReader(symbol, 'quandl', start=eps.index.min(), 
                         end = eps.index.max(),
                         api_key = 'J8qrR58jz1huGcFxGuqh')
              .resample('D')
              .last()
             .loc['2009':eps.index.max()])
company_stock.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2857 entries, 2010-06-01 to 2018-03-27
# Freq: D
# Data columns (total 12 columns):
# Open          1968 non-null float64
# High          1968 non-null float64
# Low           1968 non-null float64
# Close         1968 non-null float64
# Volume        1968 non-null float64
# ExDividend    1968 non-null float64
# SplitRatio    1968 non-null float64
# AdjOpen       1968 non-null float64
# AdjHigh       1968 non-null float64
# AdjLow        1968 non-null float64
# AdjClose      1968 non-null float64
# AdjVolume     1968 non-null float64
# dtypes: float64(12)
# memory usage: 290.2 KB

# %%
pe = company_stock.AdjClose.to_frame('price').join(eps.to_frame('eps'))
pe = pe.fillna(method='ffill').dropna()
pe['P/E Ratio'] = pe.price.div(pe.eps)
pe['P/E Ratio'].plot(lw=2, figsize=(14, 6), title='TTM P/E Ratio');

# %%
pe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2766 entries, 2010-08-31 to 2018-03-27
# Freq: D
# Data columns (total 3 columns):
# price        2766 non-null float64
# eps          2766 non-null float64
# P/E Ratio    2766 non-null float64
# dtypes: float64(3)
# memory usage: 86.4 KB

# %%
axes = pe.plot(subplots=True, figsize=(16,8), legend=False, lw=2)
axes[0].set_title('Adj. Close Price')
axes[1].set_title('Diluted Earnings per Share')
axes[2].set_title('Trailing P/E Ratio')
plt.tight_layout();

# %% [markdown]
# # Explore Additional Fields

# %%
company_nums.tag.value_counts()
# Out:
# AllocatedShareBasedCompensationExpense                                                                         1415
# CashAndCashEquivalentsFairValueDisclosure                                                                      1385
# AvailableForSaleSecurities                                                                                     1315
# AvailableForSaleSecuritiesAmortizedCost                                                                        1078
# Revenues                                                                                                        830
# GrossProfit                                                                                                     717
# FiniteLivedIntangibleAssetsNet                                                                                  712
# CostOfRevenue                                                                                                   645
# AvailableForSaleSecuritiesFairValueDisclosure                                                                   632
# FiniteLivedIntangibleAssetsGross                                                                                632
# FiniteLivedIntangibleAssetsAccumulatedAmortization                                                              632
# GrossProfitAsPercentageOfRevenue                                                                                620
# ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedNumber       480
# StockholdersEquity                                                                                              474
# AvailableForSaleSecuritiesAccumulatedGrossUnrealizedGainBeforeTax                                               444
# AvailableForSaleSecuritiesAccumulatedGrossUnrealizedLossBeforeTax                                               444
# AvailableForSaleSecuritiesContinuousUnrealizedLossPositionLessThanTwelveMonthsFairValue                         416
# ShortTermInvestments                                                                                            338
# NetIncomeLoss                                                                                                   323
# AvailableForSaleSecuritiesGrossUnrealizedGains                                                                  309
# AvailableForSaleSecuritiesGrossUnrealizedLoss                                                                   302
# AvailableforsaleSecuritiesGrossUnrealizedGain                                                                   298
# AvailableForSaleSecuritiesGrossUnrealizedLosses1                                                                298
# AssetsFairValueDisclosure                                                                                       280
# ForeignCurrencyContractsLiabilityFairValueDisclosure                                                            280
# ForeignCurrencyContractAssetFairValueDisclosure                                                                 280
# DerivativeFairValueOfDerivativeAsset                                                                            278
# LiabilitiesFairValueDisclosure                                                                                  276
# DerivativeFairValueOfDerivativeLiability                                                                        272
# ShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeitedInPeriod     266
#                                                                                                                ...
# OtherAdjustmentsChangeToPreviousEstimates                                                                         1
# LesseeOperatingLeaseLiabilityPaymentsDue                                                                          1
# TransitiontaxexpenseoflongtermincometaxespayableduetotheTaxCutsandJobsAct                                         1
# OperatingLeaseWeightedAverageDiscountRatePercent                                                                  1
# PercentageofRestructuringChargesScheduledtobePaidin2016                                                           1
# IndefiniteLivedIntangibleAssetsExcludingGoodwill                                                                  1
# TaxchargeduetoTaxCutsandJobsAct                                                                                   1
# Fairvalueofinterestrateswapoffsettingcarryingvalueofnotesasset                                                    1
# LesseeOperatingLeaseLeaseNotYetCommencedAmount                                                                    1
# ReclassificationoflongtermincometaxespayabletoshorttermincometaxespayableduetoTaxCutsandJobsAct                   1
# MinimumPercentatgeOfEarningsToBeAchievedOnBudgetedEarningsToQualifyForProfitSharingPlan                           1
# PercentageOfEligibleEmployeeContributionToRetirementSavingsPlan                                                   1
# OptionsGrantedtoExistingDirectors                                                                                 1
# RightOfUseAssetObtainedInExchangeForOperatingLeaseLiability                                                       1
# ExpectedDividendYieldOfOptionValuationModel                                                                       1
# MarketableSecuritiesRealizedGainLossOtherThanTemporaryImpairmentsAmount                                           1
# PurchasePriceOfRealProperty                                                                                       1
# IncomeTaxReconciliationTaxSettlementsForeign                                                                      1
# NetUnrealizedGainsOnDerivativeInstrumentsDesignatedAsHedgingInstrumentsReclassificationAdjustments                1
# RestructuringAdjustmentsToGoodwill                                                                                1
# NetUnrealizedGainsOnDerivativeInstrumentsDesignatedAsHedgingInstrumentsIncreaseOrDecrease                         1
# BusinessAcquisitionCarryingValueOfDeferredRevenueAdjustment                                                       1
# AmendedStockRepurchaseProgramAmount                                                                               1
# ShareBasedCompensationArrangementByShareBasedPaymentAwardFairValueAssumptionsRiskFreeInterestRate                 1
# PercentageRestructuringChargesScheduledtobePaid                                                                   1
# ShareBasedCompensationArrangementByShareBasedPaymentAwardDiscountFromMarketPrice                                  1
# AdjustmentsRecordedAsIncreaseDecreaseToRestructuringCharges                                                       1
# DeferredTaxAssetIntraentityTransferAssetOtherthanInventoryNetofValuationAllowance                                 1
# ImpactOfIncomeTaxExaminationToDeferredTaxAssetsForAccruedTaxAndInterest                                           1
# BusinessExitCosts                                                                                                 1
# Name: tag, Length: 1096, dtype: int64

# %%
type(company_nums.tag.value_counts())
# Out:
# pandas.core.series.Series

# %%
company_nums.tag.value_counts().to_csv()
# Out:
# 'AllocatedShareBasedCompensationExpense,1415\nCashAndCashEquivalentsFairValueDisclosure,1385\nAvailableForSaleSecurities,1315\nAvailableForSaleSecuritiesAmortizedCost,1078\nRevenues,830\nGrossProfit,717\nFiniteLivedIntangibleAssetsNet,712\nCostOfRevenue,645\nAvailableForSaleSecuritiesFairValueDisclosure,632\nFiniteLivedIntangibleAssetsGross,632\nFiniteLivedIntangibleAssetsAccumulatedAmortization,632\nGrossProfitAsPercentageOfRevenue,620\nShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsNonvestedNumber,480\nStockholdersEquity,474\nAvailableForSaleSecuritiesAccumulatedGrossUnrealizedGainBeforeTax,444\nAvailableForSaleSecuritiesAccumulatedGrossUnrealizedLossBeforeTax,444\nAvailableForSaleSecuritiesContinuousUnrealizedLossPositionLessThanTwelveMonthsFairValue,416\nShortTermInvestments,338\nNetIncomeLoss,323\nAvailableForSaleSecuritiesGrossUnrealizedGains,309\nAvailableForSaleSecuritiesGrossUnrealizedLoss,302\nAvailableforsaleSecuritiesGrossUnrealizedGain,298\nAvailableForSaleSecuritiesGrossUnrealizedLosses1,298\nAssetsFairValueDisclosure,280\nForeignCurrencyContractsLiabilityFairValueDisclosure,280\nForeignCurrencyContractAssetFairValueDisclosure,280\nDerivativeFairValueOfDerivativeAsset,278\nLiabilitiesFairValueDisclosure,276\nDerivativeFairValueOfDerivativeLiability,272\nShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsForfeitedInPeriod,266\nDerivativeInstrumentsNotDesignatedAsHedgingInstrumentsGainLossNet,251\nDerivativeInstrumentsGainLossReclassifiedFromAccumulatedOCIIntoIncomeEffectivePortionNet,251\nDerivativeInstrumentsGainLossRecognizedInIncomeIneffectivePortionAndAmountExcludedFromEffectivenessTestingNet,248\nRestructuringReserve,244\nEarningsPerShareBasic,243\nEarningsPerShareDiluted,243\nDeferredCompensationPlanAssets,240\nShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsGrantsInPeriod,237\nAvailableForSaleSecuritiesContinuousUnrealizedLossPositionTwelveMonthsOrLongerFairValue,217\nDerivativeInstrumentsGainLossRecognizedInOtherComprehensiveIncomeEffectivePortionNet,216\nCashAndCashEquivalentsAtCarryingValue,204\nGoodwill,202\nPropertyPlantAndEquipmentNet,190\nAvailableForSaleSecuritiesContinuousUnrealizedLossPositionLessThan12MonthsAccumulatedLoss,184\nStockIssuedDuringPeriodValueTreasuryStockReissued,183\nIncomeLossFromContinuingOperationsBeforeIncomeTaxesMinorityInterestAndIncomeLossFromEquityMethodInvestments,180\nRestructuringAndRelatedCostIncurredCost,161\nForeignCurrencyTransactionGainLossBeforeTax,159\nCashEquivalentsAtCarryingValue,157\nSellingAndMarketingExpense,157\nIncomeTaxExpenseBenefit,157\nWeightedAverageNumberOfSharesOutstandingBasic,156\nGainLossOnInvestments,156\nOtherNonoperatingIncome,156\nNonoperatingIncomeExpense,156\nInterestExpense,156\nWeightedAverageNumberOfDilutedSharesOutstanding,156\nOtherComprehensiveIncomeLossNetOfTax,152\nPaymentsForRepurchaseOfCommonStock,150\nShareBasedCompensationArrangementByShareBasedPaymentAwardEquityInstrumentsOtherThanOptionsVestedInPeriod,146\nAvailableForSaleSecuritiesContinuousUnrealizedLossPosition12MonthsOrLongerAccumulatedLoss,146\nShareBasedCompensationArrangementByShareBasedPaymentAwardFairValueAssumptionsRiskFreeInterestRateMinimum,142\nResearchAndDevelopmentExpenseSoftwareExcludingAcquiredInProcessCost,142\nOperatingExpenses,142\nOperatingIncomeLoss,142\nShareBasedCompensationArrangementByShareBasedPaymentAwardFairValueAssumptionsRiskFreeInterestRateMaximum,142\nGeneralAndAdministrativeExpense,142\nShareBasedCompensationArrangementByShareBasedPaymentAwardFairValueAssumptionsExpectedVolatilityRateMinimum,141\nShareBasedCompensationArrangementByShareBasedPaymentAwardFairValueAssumptionsExpectedVolatilityRateMaximum,141\nOtherComprehensiveIncomeUnrealizedGainLossOnDerivativesArisingDuringPeriodNetOfTax,139\nAmortizationOfIntangibleAssets,139\nVestedAndExpectedToVestShares,137\nIncrementalCommonSharesAttributableToShareBasedPaymentArrang ...

# %%
# # Filter by tag; keep only values measuring 1 quarter
# import ddate
# current_liabilities = company_nums[(company_nums.tag == 'LiabilitiesCurrent',['ddate', 'value'])]
# current_assets = company_nums[(company_nums.tag == 'AssetsCurrent',['ddate', 'value'])]
# current_ratio  = [(current_assets / current_liabilities)]
      

# Keep only most recent data point from each filing
#eps = eps.groupby('adsh').apply(lambda x: x.nlargest(n=1, columns=['ddate']))


#eps = eps.rolling(4,min_periods=4).sum().dropna()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-188-055431b8c72a> in <module>
#       1 # Filter by tag; keep only values measuring 1 quarter
#       2 import ddate
# ----> 3 current_liabilities = company_nums[(company_nums.tag == 'LiabilitiesCurrent',['ddate', 'value'])]
#       4 current_assets = company_nums[(company_nums.tag == 'AssetsCurrent',['ddate', 'value'])]
#       5 current_ratio  = [(current_assets / current_liabilities)]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(6840       False
# 6841       False
# 6842       False
# 6843       False
# 6844       False
# 6845       False
# 6846       False
# 6847       False
# 6848       False
# 6849       False
# 6850       False
# 6851       False
# 6852       False
# 6853       False
# 6854       False
# 6855       False
# 6856       False
# 6857       False
# 6858       False
# 6859       False
# 37077      False
# 37078      False
# 37079      False
# 37080      False
# 37081      False
# 37082      False
# 37083      False
# 37084      False
# 37085      False
# 37086      False
#            ...
# 5092728    False
# 5092729    False
# 5092730    False
# 5092731    False
# 5092732    False
# 5092733    False
# 5092734    False
# 5092735    False
# 5092736    False
# 5092737    False
# 5092738    False
# 5092739    False
# 5092740    False
# 5092741    False
# 5092742    False
# 5092744    False
# 5092745    False
# 5092750    False
# 5092752    False
# 5092754    False
# 5092755    False
# 5092756    False
# 5092757    False
# 5092758    False
# 5092759    False
# 5092760    False
# 5092761    False
# 5092762    False
# 5092763    False
# 5092764    False
# Name: tag, Length: 49449, dtype: bool, ['ddate', 'value'])' is an invalid key

# %%
fields = ['EarningsPerShareDiluted',
          'PaymentsOfDividendsCommonStock',
          'WeightedAverageNumberOfDilutedSharesOutstanding',
          'OperatingIncomeLoss',
          'NetIncomeLoss',
          'GrossProfit']

# %% [markdown]
# # Dividends per Share

# %%
dividends = (company_nums
             .loc[company_nums.tag == 'PaymentsOfDividendsCommonStock', ['ddate', 'value']]
             .groupby('ddate')
             .mean())
shares = (company_nums
          .loc[company_nums.tag == 'WeightedAverageNumberOfDilutedSharesOutstanding', ['ddate', 'value']]
          .drop_duplicates()
          .groupby('ddate')
          .mean())
df = dividends.div(shares) #.dropna()
ax = df.plot.bar(figsize=(14, 5), title='Dividends per Share', legend=False)
ax.xaxis.set_major_formatter(mticker.FixedFormatter(df.index.strftime('%Y-%m')))

# %% [markdown]
# # Bonus: Textual Information¶

# %%
txt = pd.read_parquet(data_path / '2020_2' / 'parquet' /  'txt.parquet')

# %%
txt.head()
# Out:
#                    adsh                    tag   version     ddate  qtrs  \
# 0  0000006201-20-000051          AmendmentFlag  dei/2019  20200331     0
# 1  0000006201-20-000051          AmendmentFlag  dei/2019  20200331     0
# 2  0000006201-20-000051  EntityCentralIndexKey  dei/2019  20200331     0
# 3  0000006201-20-000051  EntityCentralIndexKey  dei/2019  20200331     0
# 4  0000006201-20-000051           DocumentType  dei/2019  20200331     0
#
#    iprx   lang   dcml  durp  datp                                dimh  dimn  \
# 0     0  en-US  32767   0.0  -1.0                          0x00000000     0
# 1     0  en-US  32767   0.0  -1.0  0xbcb3e4b456b208133382b5ccc841019f     1
# 2     0  en-US  32767   0.0  -1.0                          0x00000000     0
# 3     0  en-US  32767   0.0  -1.0  0xbcb3e4b456b208133382b5ccc841019f     1
# 4     0  en-US  32767   0.0  -1.0                          0x00000000     0
#
#   coreg  escaped  srclen  txtlen footnote  footlen  \
# 0  None        0       5       5     None        0
# 1  None        0       5       5     None        0
# 2  None        0      10      10     None        0
# 3  None        0      10      10     None        0
# 4  None        0       3       3     None        0
#
#                                              context       value
# 0                                            D2020Q2       false
# 1  D2020Q2_srt_ConsolidatedEntitiesAxis_srt_Subsi...       false
# 2                                            D2020Q2  0000006201
# 3  D2020Q2_srt_ConsolidatedEntitiesAxis_srt_Subsi...  0000004515
# 4                                            D2020Q2         8-K
